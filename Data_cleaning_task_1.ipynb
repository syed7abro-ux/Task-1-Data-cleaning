# %% [markdown]
# <a href="https://colab.research.google.com/github/syed7abro-ux/Task-1-Data-cleaning/blob/main/Data_cleaning_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 1: Data Cleaning - Netflix Dataset

# %%
# STEP 1: Upload Dataset
from google.colab import files
uploaded = files.upload()

# %%
# STEP 2: Import Libraries & Load Data
import pandas as pd

df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4850/1412982001.py in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 df = pd.read_csv("netflix_titles.csv")
#       5 df.head()
#
# ...

# %%
# STEP 3: Check Data
print("INFO:")
print(df.info())

print("\nDESCRIBE:")
print(df.describe())

print("\nMISSING VALUES:")
print(df.isnull().sum())

# %%
# STEP 4: Handle Missing Values
df['director'].fillna("Unknown", inplace=True)
df['cast'].fillna("Not Available", inplace=True)
df['country'].fillna("Unknown", inplace=True)

df.dropna(subset=['date_added'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4850/2528343035.py in <cell line: 0>()
#       1 # STEP 4: Handle Missing Values
# ----> 2 df['director'].fillna("Unknown", inplace=True)
#       3 df['cast'].fillna("Not Available", inplace=True)
#       4 df['country'].fillna("Unknown", inplace=True)
#       5
#
# NameError: name 'df' is not defined

# %%
# STEP 5: Remove Duplicates
df.drop_duplicates(inplace=True)

# %%
# STEP 6: Standardize Text
df['type'] = df['type'].str.lower()
df['country'] = df['country'].str.title()

# %%
# STEP 7: Fix Date Format
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df['date_added'] = df['date_added'].dt.strftime('%d-%m-%Y')

# %%
# STEP 8: Rename Columns
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
# STEP 9: Fix Data Types
df['release_year'] = df['release_year'].astype(int)

# %%
# STEP 10: Save Cleaned Dataset
df.to_csv("cleaned_netflix_data.csv", index=False)

# %%
# STEP 11: Download Cleaned File
files.download("cleaned_netflix_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4850/325962723.py in <cell line: 0>()
#       1 # STEP 11: Download Cleaned File
# ----> 2 files.download("cleaned_netflix_data.csv")
#
# NameError: name 'files' is not defined
